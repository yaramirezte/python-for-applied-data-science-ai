# %%
import pandas as pd
# Create a Series from a list
data = [10, 20, 30, 40, 50]
s = pd.Series(data)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
print(s[1:4])   # Access a range of elements by label
# Out:
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
print(s.iloc[3]) # Access the element at position 3 (value 40)
# Out:
# 40

# %%
print(s[2])     # Access the element with label 2 (value 30)
# Out:
# 30

# %%
import pandas as pd
# Creating a DataFrame from a dictionary
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
        'Age': [25, 30, 35, 28],
        'City': ['New York', 'San Francisco', 'Los Angeles', 'Chicago']}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   28        Chicago

# %%
print(df['Name'])  # Access the 'Name' column
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: object

# %%
print(df.iloc[2])   # Access the third row by position
# Out:
# Name        Charlie
# Age              35
# City    Los Angeles
# Name: 2, dtype: object

# %%
print(df.loc[1])    # Access the second row by label
# Out:
# Name              Bob
# Age                30
# City    San Francisco
# Name: 1, dtype: object

# %%
print(df[['Name', 'Age']])  # Select specific columns
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   28

# %%
print(df[1:3])             # Select specific rows
# Out:
#       Name  Age           City
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles

# %%
unique_dates = df['Age'].unique()
print(unique_dates)
# Out:
# [25 30 35 28]

# %%
shape_dates = df.shape
print(shape_dates)
# Out:
# (4, 3)

# %%
high_above_102 = df[df['Age'] > 25]
print(high_above_102)
# Out:
#       Name  Age           City
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   28        Chicago

# %%
df.to_csv('trading_data.csv', index=False)

# %%
#write your code here
infoEstudents= {"Student":["David", "Samuel", "Terry", "Evan"],"Age":[27,24,22,32],"Country":["UK","Canada","China","USA"],"Course":["Python","Data Structures","Machine Learning","Web Development"],"Marks":[85,72,89,76]}
it=pd.DataFrame(infoEstudents)
it
# Out:
#   Student  Age Country            Course  Marks
# 0   David   27      UK            Python     85
# 1  Samuel   24  Canada   Data Structures     72
# 2   Terry   22   China  Machine Learning     89
# 3    Evan   32     USA   Web Development     76

# %%
b=it[["Marks"]]
b
# Out:
#    Marks
# 0     85
# 1     72
# 2     89
# 3     76

# %%
c=it[["Country","Course"]]
c
# Out:
#   Country            Course
# 0      UK            Python
# 1  Canada   Data Structures
# 2   China  Machine Learning
# 3     USA   Web Development

# %%
x = it['Student']
x
# Out:
# 0     David
# 1    Samuel
# 2     Terry
# 3      Evan
# Name: Student, dtype: object

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
# Access the value on the first row and the first column

it.iloc[0, 0]
# Out:
# 'David'

# %%
# Access the value on the first row and the third column

df.iloc[0,2]
# Out:
# 'New York'

# %%
# Access the column using the name

it.loc[0, "Course"]
# Out:
# 'Python'

# %% [markdown]
# Let us create a new dataframe. Now, let us set the "Student" column as an index column using the method set_index().

# %%
it2=it
it2=it2.set_index("Student")
it2
# Out:
#          Age Country            Course  Marks
# Student
# David     27      UK            Python     85
# Samuel    24  Canada   Data Structures     72
# Terry     22   China  Machine Learning     89
# Evan      32     USA   Web Development     76

# %%
#To display the first 2 rows of new dataframe
it2.head(2)
# Out:
#          Age Country           Course  Marks
# Student
# David     27      UK           Python     85
# Samuel    24  Canada  Data Structures     72

# %%
#Now, let us access the column using the name
it2.loc["Samuel", "Country"]
# Out:
# 'Canada'

# %%
it2.loc["David","Age"]
# Out:
# 27

# %%
it2.iloc[2,2]
# Out:
# 'Machine Learning'

# %%
it.iloc[1:2, 1:4]
# Out:
#    Age Country           Course
# 1   24  Canada  Data Structures

# %% [markdown]
# let us do the slicing using loc() function on old dataframe it where index column is having labels as 0,1,2

# %%
it.loc[1:2,'Age':'Course']
# Out:
#    Age Country            Course
# 1   24  Canada   Data Structures
# 2   22   China  Machine Learning

# %%
#let us do the slicing using loc() function on new dataframe it2 where index column is Students having labels: Terry, Samuel, evan
it2.loc['Terry':'Evan', 'Age':'Marks']
# Out:
#          Age Country            Course  Marks
# Student
# Terry     22   China  Machine Learning     89
# Evan      32     USA   Web Development     76

# %%
it.loc[2:3, 'Age':'Marks']
# Out:
#    Age Country            Course  Marks
# 2   22   China  Machine Learning     89
# 3   32     USA   Web Development     76
